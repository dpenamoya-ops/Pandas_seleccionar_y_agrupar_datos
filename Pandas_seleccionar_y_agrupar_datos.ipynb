# %% [markdown]
# <a href="https://colab.research.google.com/github/dpenamoya-ops/Pandas_seleccionar_y_agrupar_datos/blob/main/Pandas_seleccionar_y_agrupar_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
